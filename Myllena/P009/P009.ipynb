# %%
import pandas as pd
df2003 = pd.read_csv("dadosBrasilia/INMET_CO_DF_A001_BRASILIA_01-01-2003_A_31-12-2003.CSV", encoding='iso-8859-1', decimal=',', delimiter=';', skiprows=8)
df2003.head()
# Out:
#   DATA (YYYY-MM-DD) HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0        2003-01-01      00:00                               0.0
# 1        2003-01-01      01:00                               0.0
# 2        2003-01-01      02:00                               0.0
# 3        2003-01-01      03:00                               0.0
# 4        2003-01-01      04:00                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              886.9
# 1                                              887.3
# 2                                              887.8
# 3                                              886.9
# 4                                              886.8
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            887.0
# 1                                            887.3
# 2                                            887.8
# 3                                            887.8
# 4                                            886.9
#
#    PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (KJ/m²)  \
# 0                                             886.5                    -9999
# 1                                             886.9                    -9999
# 2                                             887.3                    -9999
# 3                                             886.9                    -9999
# 4                                             886.7                    -9999
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                          20.3
# 1                                          19.9
# 2                                          19.8
# 3                                          19.5
# 4                                          19.2
#
#    TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                  18.8
# 1                                  18.5
# 2                                  18.5
# 3                                  18.5
# 4                                  18.0
#
#    TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                        20.4
# 1                                        20.3
# 2                                        20.1
# 3                                        19.8
# 4                                        19.5
#
#    TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                        20.2
# 1                                        19.9
# 2                                        19.8
# 3                                        19.5
# 4                                        19.2
#
#    TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                              18.9
# 1                                              18.8
# 2                                              18.8
# 3                                              18.6
# 4                                              18.5
#
#    TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                              18.7
# 1                                              18.5
# 2                                              18.4
# 3                                              18.4
# 4                                              18.0
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                        91
# 1                                        92
# 2                                        92
# 3                                        94
# 4                                        94
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                        90
# 1                                        91
# 2                                        92
# 3                                        92
# 4                                        93
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                   91                                   308
# 1                                   92                                   302
# 2                                   92                                   302
# 3                                   94                                   295
# 4                                   93                                   313
#
#    VENTO, RAJADA MAXIMA (m/s)  VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                         2.1                              1.4          NaN
# 1                         2.2                              1.3          NaN
# 2                         2.7                              1.6          NaN
# 3                         3.4                              2.0          NaN
# 4                         3.9                              2.5          NaN

# %%
df2013 = pd.read_csv("dadosBrasilia/INMET_CO_DF_A001_BRASILIA_01-01-2013_A_31-12-2013.CSV", encoding='iso-8859-1', decimal=',', delimiter=';', skiprows=8)
df2013.head()
# Out:
#   DATA (YYYY-MM-DD) HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0        2013-01-01      00:00                               0.0
# 1        2013-01-01      01:00                               0.0
# 2        2013-01-01      02:00                               0.0
# 3        2013-01-01      03:00                               0.0
# 4        2013-01-01      04:00                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              885.7
# 1                                              886.5
# 2                                              886.9
# 3                                              886.5
# 4                                              886.0
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            885.7
# 1                                            886.5
# 2                                            886.9
# 3                                            886.9
# 4                                            886.5
#
#    PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (KJ/m²)  \
# 0                                             885.1                  -9999.0
# 1                                             885.7                  -9999.0
# 2                                             886.5                  -9999.0
# 3                                             886.5                  -9999.0
# 4                                             886.0                  -9999.0
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                          24.1
# 1                                          23.5
# 2                                          23.3
# 3                                          22.8
# 4                                          22.4
#
#    TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                  14.2
# 1                                  14.5
# 2                                  14.5
# 3                                  14.6
# 4                                  14.5
#
#    TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                        25.0
# 1                                        24.2
# 2                                        23.5
# 3                                        23.3
# 4                                        22.9
#
#    TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                        24.1
# 1                                        23.4
# 2                                        23.2
# 3                                        22.8
# 4                                        22.2
#
#    TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                              14.4
# 1                                              14.6
# 2                                              14.7
# 3                                              14.7
# 4                                              14.6
#
#    TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                              13.9
# 1                                              14.2
# 2                                              14.4
# 3                                              14.4
# 4                                              14.3
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                        54
# 1                                        58
# 2                                        59
# 3                                        60
# 4                                        62
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                        50
# 1                                        54
# 2                                        56
# 3                                        57
# 4                                        59
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                   54                                   112
# 1                                   57                                   110
# 2                                   58                                    91
# 3                                   60                                    81
# 4                                   61                                    86
#
#    VENTO, RAJADA MAXIMA (m/s)  VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                         4.6                              2.3          NaN
# 1                         5.0                              2.7          NaN
# 2                         5.4                              3.4          NaN
# 3                         5.4                              3.1          NaN
# 4                         5.3                              2.9          NaN

# %%
df2023 = pd.read_csv("dadosBrasilia/INMET_CO_DF_A001_BRASILIA_01-01-2023_A_31-12-2023.CSV", encoding='iso-8859-1', decimal=',', delimiter=';', skiprows=8)
df2023.head()
# Out:
#          Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2023/01/01  0000 UTC                               0.0
# 1  2023/01/01  0100 UTC                               0.0
# 2  2023/01/01  0200 UTC                               0.0
# 3  2023/01/01  0300 UTC                               0.0
# 4  2023/01/01  0400 UTC                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              887.7
# 1                                              888.1
# 2                                              887.8
# 3                                              887.8
# 4                                              887.6
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            887.7
# 1                                            888.1
# 2                                            888.1
# 3                                            887.9
# 4                                            887.9
#
#    PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (Kj/m²)  \
# 0                                             887.2                      NaN
# 1                                             887.7                      NaN
# 2                                             887.8                      NaN
# 3                                             887.7                      NaN
# 4                                             887.6                      NaN
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                          20.1
# 1                                          19.2
# 2                                          19.3
# 3                                          19.3
# 4                                          19.7
#
#    TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                  17.9
# 1                                  17.5
# 2                                  17.6
# 3                                  17.7
# 4                                  18.1
#
#    TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                        20.9
# 1                                        20.1
# 2                                        19.5
# 3                                        19.4
# 4                                        19.7
#
#    TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                        20.0
# 1                                        19.2
# 2                                        19.0
# 3                                        19.1
# 4                                        19.1
#
#    TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                              19.2
# 1                                              17.8
# 2                                              17.8
# 3                                              17.8
# 4                                              18.1
#
#    TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                              17.8
# 1                                              17.4
# 2                                              17.3
# 3                                              17.5
# 4                                              17.4
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                      91.0
# 1                                      90.0
# 2                                      90.0
# 3                                      91.0
# 4                                      91.0
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                      87.0
# 1                                      87.0
# 2                                      89.0
# 3                                      90.0
# 4                                      90.0
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                 87.0                                 187.0
# 1                                 90.0                                 153.0
# 2                                 90.0                                 145.0
# 3                                 91.0                                 162.0
# 4                                 90.0                                 140.0
#
#    VENTO, RAJADA MAXIMA (m/s)  VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                         3.3                              1.2          NaN
# 1                         2.9                              0.8          NaN
# 2                         2.5                              1.5          NaN
# 3                         3.2                              1.4          NaN
# 4                         5.7                              2.7          NaN

# %%
hora23 = df2023["Hora UTC"].values
hora23 = [h.split(" ")[0][:2] + ":" + h.split(" ")[0][2:] for h in hora23]
df2023["Hora UTC"] = hora23
df2023.head()
# Out:
#          Data Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2023/01/01    00:00                               0.0
# 1  2023/01/01    01:00                               0.0
# 2  2023/01/01    02:00                               0.0
# 3  2023/01/01    03:00                               0.0
# 4  2023/01/01    04:00                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              887.7
# 1                                              888.1
# 2                                              887.8
# 3                                              887.8
# 4                                              887.6
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            887.7
# 1                                            888.1
# 2                                            888.1
# 3                                            887.9
# 4                                            887.9
#
#    PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (Kj/m²)  \
# 0                                             887.2                      NaN
# 1                                             887.7                      NaN
# 2                                             887.8                      NaN
# 3                                             887.7                      NaN
# 4                                             887.6                      NaN
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                          20.1
# 1                                          19.2
# 2                                          19.3
# 3                                          19.3
# 4                                          19.7
#
#    TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                  17.9
# 1                                  17.5
# 2                                  17.6
# 3                                  17.7
# 4                                  18.1
#
#    TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                        20.9
# 1                                        20.1
# 2                                        19.5
# 3                                        19.4
# 4                                        19.7
#
#    TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                        20.0
# 1                                        19.2
# 2                                        19.0
# 3                                        19.1
# 4                                        19.1
#
#    TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                              19.2
# 1                                              17.8
# 2                                              17.8
# 3                                              17.8
# 4                                              18.1
#
#    TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                              17.8
# 1                                              17.4
# 2                                              17.3
# 3                                              17.5
# 4                                              17.4
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                      91.0
# 1                                      90.0
# 2                                      90.0
# 3                                      91.0
# 4                                      91.0
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                      87.0
# 1                                      87.0
# 2                                      89.0
# 3                                      90.0
# 4                                      90.0
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                 87.0                                 187.0
# 1                                 90.0                                 153.0
# 2                                 90.0                                 145.0
# 3                                 91.0                                 162.0
# 4                                 90.0                                 140.0
#
#    VENTO, RAJADA MAXIMA (m/s)  VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                         3.3                              1.2          NaN
# 1                         2.9                              0.8          NaN
# 2                         2.5                              1.5          NaN
# 3                         3.2                              1.4          NaN
# 4                         5.7                              2.7          NaN

# %%
df2023.rename(columns={'Data':'DATA (YYYY-MM-DD)', 'Hora UTC':'HORA (UTC)', 'RADIACAO GLOBAL (Kj/m²)': 'RADIACAO GLOBAL (KJ/m²)'}, inplace=True)

# %%
df = pd.concat([df2003, df2013, df2023])

# %%
data = df["DATA (YYYY-MM-DD)"].values
index = pd.DatetimeIndex(data, name="Data")
df.drop("DATA (YYYY-MM-DD)", axis=1, inplace=True)
df.set_index(index, inplace=True)

# %%
mi = []
for columns in df.columns:
    a = (columns,"")
    if(columns.find("PRESSAO")>-1 or columns.find("PRESSÃO")>-1):
        a = ("Pressão",columns)
    if(columns.find("TEMPERATURA")>-1):
        a = ("Temperatura",columns)
    if(columns.find("UMIDADE")>-1):
        a = ("Umidade",columns)
    if(columns.find("VENTO")>-1):
        a = ("Velocidade do Vento",columns)
    mi.append(a)

# %%
df.columns = pd.MultiIndex.from_tuples(mi)
df
# Out:
#            HORA (UTC) PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
#
# Data
# 2003-01-01      00:00                              0.0
# 2003-01-01      01:00                              0.0
# 2003-01-01      02:00                              0.0
# 2003-01-01      03:00                              0.0
# 2003-01-01      04:00                              0.0
# ...               ...                              ...
# 2023-12-31      19:00                              0.0
# 2023-12-31      20:00                              0.0
# 2023-12-31      21:00                              0.0
# 2023-12-31      22:00                              0.0
# 2023-12-31      23:00                              0.0
#
#                                                          Pressão  \
#            PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)
# Data
# 2003-01-01                                              886.9
# 2003-01-01                                              887.3
# 2003-01-01                                              887.8
# 2003-01-01                                              886.9
# 2003-01-01                                              886.8
# ...                                                       ...
# 2023-12-31                                              884.2
# 2023-12-31                                              883.7
# 2023-12-31                                              883.5
# 2023-12-31                                              884.5
# 2023-12-31                                              885.3
#
#                                                             \
#            PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)
# Data
# 2003-01-01                                           887.0
# 2003-01-01                                           887.3
# 2003-01-01                                           887.8
# 2003-01-01                                           887.8
# 2003-01-01                                           886.9
# ...                                                    ...
# 2023-12-31                                           885.2
# 2023-12-31                                           884.3
# 2023-12-31                                           883.7
# 2023-12-31                                           884.5
# 2023-12-31                                           885.3
#
#                                                              \
#            PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)
# Data
# 2003-01-01                                            886.5
# 2003-01-01                                            886.9
# 2003-01-01                                            887.3
# 2003-01-01                                            886.9
# 2003-01-01                                            886.7
# ...                                                     ...
# 2023-12-31                                            884.2
# 2023-12-31                                            883.7
# 2023-12-31                                            883.4
# 2023-12-31                                            883.5
# 2023-12-31                                            884.5
#
#            RADIACAO GLOBAL (KJ/m²)  \
#
# Data
# 2003-01-01                 -9999.0
# 2003-01-01                 -9999.0
# 2003-01-01                 -9999.0
# 2003-01-01                 -9999.0
# 2003-01-01                 -9999.0
# ...                            ...
# 2023-12-31                  1252.2
# 2023-12-31                  1178.8
# 2023-12-31                   873.0
# 2023-12-31                   104.0
# 2023-12-31                     NaN
#
#                                             Temperatura  \
#            TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
# Data
# 2003-01-01                                         20.3
# 2003-01-01                                         19.9
# 2003-01-01                                         19.8
# 2003-01-01                                         19.5
# 2003-01-01                                         19.2
# ...                                                 ...
# 2023-12-31                                         26.1
# 2023-12-31                                         27.7
# 2023-12-31                                         25.5
# 2023-12-31                                         23.4
# 2023-12-31                                         22.6
#
#                                                  \
#            TEMPERATURA DO PONTO DE ORVALHO (°C)
# Data
# 2003-01-01                                 18.8
# 2003-01-01                                 18.5
# 2003-01-01                                 18.5
# 2003-01-01                                 18.5
# 2003-01-01                                 18.0
# ...                                         ...
# 2023-12-31                                 18.4
# 2023-12-31                                 18.1
# 2023-12-31                                 17.4
# 2023-12-31                                 18.2
# 2023-12-31                                 18.6
#
#                                                        \
#            TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# Data
# 2003-01-01                                       20.4
# 2003-01-01                                       20.3
# 2003-01-01                                       20.1
# 2003-01-01                                       19.8
# 2003-01-01                                       19.5
# ...                                               ...
# 2023-12-31                                       28.1
# 2023-12-31                                       27.7
# 2023-12-31                                       27.7
# 2023-12-31                                       25.5
# 2023-12-31                                       23.4
#
#                                                        \
#            TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)
# Data
# 2003-01-01                                       20.2
# 2003-01-01                                       19.9
# 2003-01-01                                       19.8
# 2003-01-01                                       19.5
# 2003-01-01                                       19.2
# ...                                               ...
# 2023-12-31                                       26.0
# 2023-12-31                                       25.8
# 2023-12-31                                       25.5
# 2023-12-31                                       23.4
# 2023-12-31                                       22.3
#
#                                                              \
#            TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)
# Data
# 2003-01-01                                             18.9
# 2003-01-01                                             18.8
# 2003-01-01                                             18.8
# 2003-01-01                                             18.6
# 2003-01-01                                             18.5
# ...                                                     ...
# 2023-12-31                                             19.0
# 2023-12-31                                             18.2
# 2023-12-31                                             18.0
# 2023-12-31                                             18.2
# 2023-12-31                                             18.6
#
#                                                              \
#            TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)
# Data
# 2003-01-01                                             18.7
# 2003-01-01                                             18.5
# 2003-01-01                                             18.4
# 2003-01-01                                             18.4
# 2003-01-01                                             18.0
# ...                                                     ...
# 2023-12-31                                             16.9
# 2023-12-31                                             16.9
# 2023-12-31                                             16.9
# 2023-12-31                                             17.4
# 2023-12-31                                             18.3
#
#                                             Umidade  \
#            UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)
# Data
# 2003-01-01                                     91.0
# 2003-01-01                                     92.0
# 2003-01-01                                     92.0
# 2003-01-01                                     94.0
# 2003-01-01                                     94.0
# ...                                             ...
# 2023-12-31                                     64.0
# 2023-12-31                                     62.0
# 2023-12-31                                     62.0
# 2023-12-31                                     72.0
# 2023-12-31                                     79.0
#
#                                                      \
#            UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)
# Data
# 2003-01-01                                     90.0
# 2003-01-01                                     91.0
# 2003-01-01                                     92.0
# 2003-01-01                                     92.0
# 2003-01-01                                     93.0
# ...                                             ...
# 2023-12-31                                     52.0
# 2023-12-31                                     53.0
# 2023-12-31                                     52.0
# 2023-12-31                                     61.0
# 2023-12-31                                     73.0
#
#                                                 \
#            UMIDADE RELATIVA DO AR, HORARIA (%)
# Data
# 2003-01-01                                91.0
# 2003-01-01                                92.0
# 2003-01-01                                92.0
# 2003-01-01                                94.0
# 2003-01-01                                93.0
# ...                                        ...
# 2023-12-31                                63.0
# 2023-12-31                                56.0
# 2023-12-31                                61.0
# 2023-12-31                                72.0
# 2023-12-31                                78.0
#
#                             Velocidade do Vento                             \
#            VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)
# Data
# 2003-01-01                                308.0                        2.1
# 2003-01-01                                302.0                        2.2
# 2003-01-01                                302.0                        2.7
# 2003-01-01                                295.0                        3.4
# 2003-01-01                                313.0                        3.9
# ...                                         ...                        ...
# 2023-12-31                                  1.0                        5.3
# 2023-12-31                                314.0                        5.2
# 2023-12-31                                300.0                        5.1
# 2023-12-31                                293.0                        4.8
# 2023-12-31                                285.0                        3.7
#
#                                            Unnamed: 19
#            VENTO, VELOCIDADE HORARIA (m/s)
# Data
# 2003-01-01                             1.4         NaN
# 2003-01-01                             1.3         NaN
# 2003-01-01                             1.6         NaN
# 2003-01-01                             2.0         NaN
# 2003-01-01                             2.5         NaN
# ...                                    ...         ...
# 2023-12-31                             2.1         NaN
# 2023-12-31                             1.9         NaN
# 2023-12-31                             2.7         NaN
# 2023-12-31                             2.0         NaN
# 2023-12-31                             1.4         NaN
#
# [26280 rows x 19 columns]

# %%
import matplotlib.pyplot as plt
idf = df.groupby([df.index.year])["PRECIPITAÇÃO TOTAL, HORÁRIO (mm)"].cumsum()
fig, axes = plt.subplots(3, 1, figsize=(10, 10))
for ano, ax in zip(['2003', '2013', '2023'], axes):
    idf.loc[ano].plot(ax=ax, title=ano, ylabel="Precipitação Acumulada")
plt.subplots_adjust(wspace=1, hspace=1)

# %%
import numpy as np
idf = df.groupby([df.index.year, df.index.month])["Temperatura"].mean()
idf = idf.loc[:]["Temperatura"]
fig, axes = plt.subplots(18, 1, figsize=(10, 40), sharex=True)
for ano, ax, columns in zip(['2003', '2013', '2023']*6, axes, np.concatenate((idf.columns,idf.columns,idf.columns))):
    idf.loc[ano,][columns].plot(ax=ax, title=ano, legend=True, xlabel="Dia", ylabel="Média")
plt.subplots_adjust(wspace=1, hspace=1)

# %%
idf = df.loc[df.index.month == 6]
idf = idf.groupby([idf.index.year])["PRECIPITAÇÃO TOTAL, HORÁRIO (mm)"].cumsum()
fig, axes = plt.subplots(3, 1, figsize=(10, 10))
for ano, ax in zip(['2003', '2013', '2023'], axes):
    idf.loc[ano].plot(ax=ax, title=ano)
plt.subplots_adjust(wspace=1, hspace=1)

# %%
import numpy as np
idf = df.loc[df.index.month == 3]
idf = idf.groupby([idf.index.year, idf.index.day])["Temperatura"].mean()
idf = idf.loc[:]["Temperatura"]
fig, axes = plt.subplots(18, 1, figsize=(10, 50))
for ano, ax, columns in zip(['2003', '2013', '2023']*6, axes, np.concatenate((idf.columns,idf.columns,idf.columns))):
    idf.loc[ano,][columns].plot(ax=ax, title=ano, legend=True, xlabel="Dia")
plt.subplots_adjust(wspace=1, hspace=1)

# %%
estacao = ["Verâo" if (1 <= x  <= 3) else x for x in df.index.month]
estacao = ["Outono" if type(x) != str and (4 <= x  <= 6) else x for x in estacao]
estacao = ["Inverno" if type(x) != str and (7 <= x  <= 9) else x for x in estacao]
estacao = ["Primavera" if type(x) != str and (10 <= x  <= 12) else x for x in estacao]

# %%
tuplas = list(zip(index, estacao))
multiindex = pd.MultiIndex.from_tuples(tuplas, names=['Data', 'Estação'])
df.set_index(multiindex, inplace=True)
df
# Out:
#                      HORA (UTC) PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
#
# Data       Estação
# 2003-01-01 Verâo          00:00                              0.0
#            Verâo          01:00                              0.0
#            Verâo          02:00                              0.0
#            Verâo          03:00                              0.0
#            Verâo          04:00                              0.0
# ...                         ...                              ...
# 2023-12-31 Primavera      19:00                              0.0
#            Primavera      20:00                              0.0
#            Primavera      21:00                              0.0
#            Primavera      22:00                              0.0
#            Primavera      23:00                              0.0
#
#                                                                    Pressão  \
#                      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)
# Data       Estação
# 2003-01-01 Verâo                                                  886.9
#            Verâo                                                  887.3
#            Verâo                                                  887.8
#            Verâo                                                  886.9
#            Verâo                                                  886.8
# ...                                                                 ...
# 2023-12-31 Primavera                                              884.2
#            Primavera                                              883.7
#            Primavera                                              883.5
#            Primavera                                              884.5
#            Primavera                                              885.3
#
#                                                                       \
#                      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)
# Data       Estação
# 2003-01-01 Verâo                                               887.0
#            Verâo                                               887.3
#            Verâo                                               887.8
#            Verâo                                               887.8
#            Verâo                                               886.9
# ...                                                              ...
# 2023-12-31 Primavera                                           885.2
#            Primavera                                           884.3
#            Primavera                                           883.7
#            Primavera                                           884.5
#            Primavera                                           885.3
#
#                                                                        \
#                      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)
# Data       Estação
# 2003-01-01 Verâo                                                886.5
#            Verâo                                                886.9
#            Verâo                                                887.3
#            Verâo                                                886.9
#            Verâo                                                886.7
# ...                                                               ...
# 2023-12-31 Primavera                                            884.2
#            Primavera                                            883.7
#            Primavera                                            883.4
#            Primavera                                            883.5
#            Primavera                                            884.5
#
#                      RADIACAO GLOBAL (KJ/m²)  \
#
# Data       Estação
# 2003-01-01 Verâo                     -9999.0
#            Verâo                     -9999.0
#            Verâo                     -9999.0
#            Verâo                     -9999.0
#            Verâo                     -9999.0
# ...                                      ...
# 2023-12-31 Primavera                  1252.2
#            Primavera                  1178.8
#            Primavera                   873.0
#            Primavera                   104.0
#            Primavera                     NaN
#
#                                                       Temperatura  \
#                      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
# Data       Estação
# 2003-01-01 Verâo                                             20.3
#            Verâo                                             19.9
#            Verâo                                             19.8
#            Verâo                                             19.5
#            Verâo                                             19.2
# ...                                                           ...
# 2023-12-31 Primavera                                         26.1
#            Primavera                                         27.7
#            Primavera                                         25.5
#            Primavera                                         23.4
#            Primavera                                         22.6
#
#                                                            \
#                      TEMPERATURA DO PONTO DE ORVALHO (°C)
# Data       Estação
# 2003-01-01 Verâo                                     18.8
#            Verâo                                     18.5
#            Verâo                                     18.5
#            Verâo                                     18.5
#            Verâo                                     18.0
# ...                                                   ...
# 2023-12-31 Primavera                                 18.4
#            Primavera                                 18.1
#            Primavera                                 17.4
#            Primavera                                 18.2
#            Primavera                                 18.6
#
#                                                                  \
#                      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# Data       Estação
# 2003-01-01 Verâo                                           20.4
#            Verâo                                           20.3
#            Verâo                                           20.1
#            Verâo                                           19.8
#            Verâo                                           19.5
# ...                                                         ...
# 2023-12-31 Primavera                                       28.1
#            Primavera                                       27.7
#            Primavera                                       27.7
#            Primavera                                       25.5
#            Primavera                                       23.4
#
#                                                                  \
#                      TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)
# Data       Estação
# 2003-01-01 Verâo                                           20.2
#            Verâo                                           19.9
#            Verâo                                           19.8
#            Verâo                                           19.5
#            Verâo                                           19.2
# ...                                                         ...
# 2023-12-31 Primavera                                       26.0
#            Primavera                                       25.8
#            Primavera                                       25.5
#            Primavera                                       23.4
#            Primavera                                       22.3
#
#                                                                        \
#                      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)
# Data       Estação
# 2003-01-01 Verâo                                                 18.9
#            Verâo                                                 18.8
#            Verâo                                                 18.8
#            Verâo                                                 18.6
#            Verâo                                                 18.5
# ...                                                               ...
# 2023-12-31 Primavera                                             19.0
#            Primavera                                             18.2
#            Primavera                                             18.0
#            Primavera                                             18.2
#            Primavera                                             18.6
#
#                                                                        \
#                      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)
# Data       Estação
# 2003-01-01 Verâo                                                 18.7
#            Verâo                                                 18.5
#            Verâo                                                 18.4
#            Verâo                                                 18.4
#            Verâo                                                 18.0
# ...                                                               ...
# 2023-12-31 Primavera                                             16.9
#            Primavera                                             16.9
#            Primavera                                             16.9
#            Primavera                                             17.4
#            Primavera                                             18.3
#
#                                                       Umidade  \
#                      UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)
# Data       Estação
# 2003-01-01 Verâo                                         91.0
#            Verâo                                         92.0
#            Verâo                                         92.0
#            Verâo                                         94.0
#            Verâo                                         94.0
# ...                                                       ...
# 2023-12-31 Primavera                                     64.0
#            Primavera                                     62.0
#            Primavera                                     62.0
#            Primavera                                     72.0
#            Primavera                                     79.0
#
#                                                                \
#                      UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)
# Data       Estação
# 2003-01-01 Verâo                                         90.0
#            Verâo                                         91.0
#            Verâo                                         92.0
#            Verâo                                         92.0
#            Verâo                                         93.0
# ...                                                       ...
# 2023-12-31 Primavera                                     52.0
#            Primavera                                     53.0
#            Primavera                                     52.0
#            Primavera                                     61.0
#            Primavera                                     73.0
#
#                                                           \
#                      UMIDADE RELATIVA DO AR, HORARIA (%)
# Data       Estação
# 2003-01-01 Verâo                                    91.0
#            Verâo                                    92.0
#            Verâo                                    92.0
#            Verâo                                    94.0
#            Verâo                                    93.0
# ...                                                  ...
# 2023-12-31 Primavera                                63.0
#            Primavera                                56.0
#            Primavera                                61.0
#            Primavera                                72.0
#            Primavera                                78.0
#
#                                       Velocidade do Vento  \
#                      VENTO, DIREÇÃO HORARIA (gr) (° (gr))
# Data       Estação
# 2003-01-01 Verâo                                    308.0
#            Verâo                                    302.0
#            Verâo                                    302.0
#            Verâo                                    295.0
#            Verâo                                    313.0
# ...                                                   ...
# 2023-12-31 Primavera                                  1.0
#            Primavera                                314.0
#            Primavera                                300.0
#            Primavera                                293.0
#            Primavera                                285.0
#
#                                                  \
#                      VENTO, RAJADA MAXIMA (m/s)
# Data       Estação
# 2003-01-01 Verâo                            2.1
#            Verâo                            2.2
#            Verâo                            2.7
#            Verâo                            3.4
#            Verâo                            3.9
# ...                                         ...
# 2023-12-31 Primavera                        5.3
#            Primavera                        5.2
#            Primavera                        5.1
#            Primavera                        4.8
#            Primavera                        3.7
#
#                                                      Unnamed: 19
#                      VENTO, VELOCIDADE HORARIA (m/s)
# Data       Estação
# 2003-01-01 Verâo                                 1.4         NaN
#            Verâo                                 1.3         NaN
#            Verâo                                 1.6         NaN
#            Verâo                                 2.0         NaN
#            Verâo                                 2.5         NaN
# ...                                              ...         ...
# 2023-12-31 Primavera                             2.1         NaN
#            Primavera                             1.9         NaN
#            Primavera                             2.7         NaN
#            Primavera                             2.0         NaN
#            Primavera                             1.4         NaN
#
# [26280 rows x 19 columns]

# %%
ano = df.index.get_level_values("Data").year

# %%
idf = df.groupby([ano, "Estação"])["Temperatura"].agg(["min", "max"])
idf = idf.loc[:]["Temperatura"]
fig, axes = plt.subplots(18, 1, figsize=(10, 50))
for a, ax, columns in zip(['2003', '2013', '2023']*6, axes, np.concatenate((idf.columns,idf.columns,idf.columns))):
    idf.loc[a,][columns].plot(ax=ax, title=a, xlabel="", kind='bar')
    ax.legend([columns])
plt.subplots_adjust(wspace=1, hspace=1)

# %%
hora = df["HORA (UTC)"].values
hora = [h[:2] for h in hora]

# %%
intervalo = ["Madrugada" if (0 <= int(x) < 6) else x for x in hora]
intervalo = ["Manhã" if (x[1]!= 'a') and (6 <= int(x) < 12) else x for x in intervalo]
intervalo = ["Tarde" if (x[1]!= 'a') and (12 <= int(x) < 18) else x for x in intervalo]
intervalo = ["Noite" if (x[1]!= 'a') and (18 <= int(x) < 24) else x for x in intervalo]

# %%
tuplas = list(zip(index, estacao, intervalo))
multiindex = pd.MultiIndex.from_tuples(tuplas, names=['Data', 'Estação', 'Intervalo'])
df.set_index(multiindex, inplace=True)
df
# Out:
#                                HORA (UTC) PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
#
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada      00:00                              0.0
#                      Madrugada      01:00                              0.0
#                      Madrugada      02:00                              0.0
#                      Madrugada      03:00                              0.0
#                      Madrugada      04:00                              0.0
# ...                                   ...                              ...
# 2023-12-31 Primavera Noite          19:00                              0.0
#                      Noite          20:00                              0.0
#                      Noite          21:00                              0.0
#                      Noite          22:00                              0.0
#                      Noite          23:00                              0.0
#
#                                                                              Pressão  \
#                                PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                                              886.9
#                      Madrugada                                              887.3
#                      Madrugada                                              887.8
#                      Madrugada                                              886.9
#                      Madrugada                                              886.8
# ...                                                                           ...
# 2023-12-31 Primavera Noite                                                  884.2
#                      Noite                                                  883.7
#                      Noite                                                  883.5
#                      Noite                                                  884.5
#                      Noite                                                  885.3
#
#                                                                                 \
#                                PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                                           887.0
#                      Madrugada                                           887.3
#                      Madrugada                                           887.8
#                      Madrugada                                           887.8
#                      Madrugada                                           886.9
# ...                                                                        ...
# 2023-12-31 Primavera Noite                                               885.2
#                      Noite                                               884.3
#                      Noite                                               883.7
#                      Noite                                               884.5
#                      Noite                                               885.3
#
#                                                                                  \
#                                PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                                            886.5
#                      Madrugada                                            886.9
#                      Madrugada                                            887.3
#                      Madrugada                                            886.9
#                      Madrugada                                            886.7
# ...                                                                         ...
# 2023-12-31 Primavera Noite                                                884.2
#                      Noite                                                883.7
#                      Noite                                                883.4
#                      Noite                                                883.5
#                      Noite                                                884.5
#
#                                RADIACAO GLOBAL (KJ/m²)  \
#
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                 -9999.0
#                      Madrugada                 -9999.0
#                      Madrugada                 -9999.0
#                      Madrugada                 -9999.0
#                      Madrugada                 -9999.0
# ...                                                ...
# 2023-12-31 Primavera Noite                      1252.2
#                      Noite                      1178.8
#                      Noite                       873.0
#                      Noite                       104.0
#                      Noite                         NaN
#
#                                                                 Temperatura  \
#                                TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                                         20.3
#                      Madrugada                                         19.9
#                      Madrugada                                         19.8
#                      Madrugada                                         19.5
#                      Madrugada                                         19.2
# ...                                                                     ...
# 2023-12-31 Primavera Noite                                             26.1
#                      Noite                                             27.7
#                      Noite                                             25.5
#                      Noite                                             23.4
#                      Noite                                             22.6
#
#                                                                      \
#                                TEMPERATURA DO PONTO DE ORVALHO (°C)
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                                 18.8
#                      Madrugada                                 18.5
#                      Madrugada                                 18.5
#                      Madrugada                                 18.5
#                      Madrugada                                 18.0
# ...                                                             ...
# 2023-12-31 Primavera Noite                                     18.4
#                      Noite                                     18.1
#                      Noite                                     17.4
#                      Noite                                     18.2
#                      Noite                                     18.6
#
#                                                                            \
#                                TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                                       20.4
#                      Madrugada                                       20.3
#                      Madrugada                                       20.1
#                      Madrugada                                       19.8
#                      Madrugada                                       19.5
# ...                                                                   ...
# 2023-12-31 Primavera Noite                                           28.1
#                      Noite                                           27.7
#                      Noite                                           27.7
#                      Noite                                           25.5
#                      Noite                                           23.4
#
#                                                                            \
#                                TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                                       20.2
#                      Madrugada                                       19.9
#                      Madrugada                                       19.8
#                      Madrugada                                       19.5
#                      Madrugada                                       19.2
# ...                                                                   ...
# 2023-12-31 Primavera Noite                                           26.0
#                      Noite                                           25.8
#                      Noite                                           25.5
#                      Noite                                           23.4
#                      Noite                                           22.3
#
#                                                                                  \
#                                TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                                             18.9
#                      Madrugada                                             18.8
#                      Madrugada                                             18.8
#                      Madrugada                                             18.6
#                      Madrugada                                             18.5
# ...                                                                         ...
# 2023-12-31 Primavera Noite                                                 19.0
#                      Noite                                                 18.2
#                      Noite                                                 18.0
#                      Noite                                                 18.2
#                      Noite                                                 18.6
#
#                                                                                  \
#                                TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                                             18.7
#                      Madrugada                                             18.5
#                      Madrugada                                             18.4
#                      Madrugada                                             18.4
#                      Madrugada                                             18.0
# ...                                                                         ...
# 2023-12-31 Primavera Noite                                                 16.9
#                      Noite                                                 16.9
#                      Noite                                                 16.9
#                      Noite                                                 17.4
#                      Noite                                                 18.3
#
#                                                                 Umidade  \
#                                UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                                     91.0
#                      Madrugada                                     92.0
#                      Madrugada                                     92.0
#                      Madrugada                                     94.0
#                      Madrugada                                     94.0
# ...                                                                 ...
# 2023-12-31 Primavera Noite                                         64.0
#                      Noite                                         62.0
#                      Noite                                         62.0
#                      Noite                                         72.0
#                      Noite                                         79.0
#
#                                                                          \
#                                UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                                     90.0
#                      Madrugada                                     91.0
#                      Madrugada                                     92.0
#                      Madrugada                                     92.0
#                      Madrugada                                     93.0
# ...                                                                 ...
# 2023-12-31 Primavera Noite                                         52.0
#                      Noite                                         53.0
#                      Noite                                         52.0
#                      Noite                                         61.0
#                      Noite                                         73.0
#
#                                                                     \
#                                UMIDADE RELATIVA DO AR, HORARIA (%)
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                                91.0
#                      Madrugada                                92.0
#                      Madrugada                                92.0
#                      Madrugada                                94.0
#                      Madrugada                                93.0
# ...                                                            ...
# 2023-12-31 Primavera Noite                                    63.0
#                      Noite                                    56.0
#                      Noite                                    61.0
#                      Noite                                    72.0
#                      Noite                                    78.0
#
#                                                 Velocidade do Vento  \
#                                VENTO, DIREÇÃO HORARIA (gr) (° (gr))
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                                308.0
#                      Madrugada                                302.0
#                      Madrugada                                302.0
#                      Madrugada                                295.0
#                      Madrugada                                313.0
# ...                                                             ...
# 2023-12-31 Primavera Noite                                      1.0
#                      Noite                                    314.0
#                      Noite                                    300.0
#                      Noite                                    293.0
#                      Noite                                    285.0
#
#                                                            \
#                                VENTO, RAJADA MAXIMA (m/s)
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                        2.1
#                      Madrugada                        2.2
#                      Madrugada                        2.7
#                      Madrugada                        3.4
#                      Madrugada                        3.9
# ...                                                   ...
# 2023-12-31 Primavera Noite                            5.3
#                      Noite                            5.2
#                      Noite                            5.1
#                      Noite                            4.8
#                      Noite                            3.7
#
#                                                                Unnamed: 19
#                                VENTO, VELOCIDADE HORARIA (m/s)
# Data       Estação   Intervalo
# 2003-01-01 Verâo     Madrugada                             1.4         NaN
#                      Madrugada                             1.3         NaN
#                      Madrugada                             1.6         NaN
#                      Madrugada                             2.0         NaN
#                      Madrugada                             2.5         NaN
# ...                                                        ...         ...
# 2023-12-31 Primavera Noite                                 2.1         NaN
#                      Noite                                 1.9         NaN
#                      Noite                                 2.7         NaN
#                      Noite                                 2.0         NaN
#                      Noite                                 1.4         NaN
#
# [26280 rows x 19 columns]

# %%
idf = df.loc[df.index.get_level_values("Data").month == 9]
idf = idf.loc[idf.index.get_level_values("Data").day == 28]
idf = idf.groupby([idf.index.get_level_values("Data").year, "Intervalo"])["Temperatura"].mean()
idf = idf["Temperatura"]
idf.plot(subplots=True, kind='bar', xlabel='Ano, Intervalo', figsize=(10,20), legend=True)
# Out:
# array([<Axes: title={'center': 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'}, xlabel='Ano, Intervalo'>,
#        <Axes: title={'center': 'TEMPERATURA DO PONTO DE ORVALHO (°C)'}, xlabel='Ano, Intervalo'>,
#        <Axes: title={'center': 'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)'}, xlabel='Ano, Intervalo'>,
#        <Axes: title={'center': 'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)'}, xlabel='Ano, Intervalo'>,
#        <Axes: title={'center': 'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)'}, xlabel='Ano, Intervalo'>,
#        <Axes: title={'center': 'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)'}, xlabel='Ano, Intervalo'>],
#       dtype=object)
